# %% [markdown]
# ## Steps to follow:
#
# 1. Import the data
# 2. Explore the data and identify things that would be worth exploring
# 3. Write two functions to make two different kinds of plots using matplotlib and seaborn (one each)
# 4. It might be a good idea to look at one of the categorical variables (gender, race/ethinicity) and the test scores
# 5. Push your work back and send me a link to the repo!

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
matplotlib.rcParams['font.size'] = 18
matplotlib.rcParams['figure.dpi'] = 200

# %%
df = pd.read_csv('StudentsPerformance.csv')
df.info
# Out:
# <bound method DataFrame.info of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
prepped = df[df['test preparation course'] == 'completed']
not_prepped = df[df['test preparation course'] == 'none']

not_prepped_math = not_prepped[['math score']]
prepped_math = prepped[['math score']]

# %%
fig = plt.figure(figsize = (20, 9))

plt.hist(prepped_math['math score'], color = 'blue', edgecolor='black')

# Labels
plt.title('Math Scores of Prep Course Students')
plt.xlabel('Math Scores'); plt.ylabel('Number of Prep Course Students');

# %%
fig = plt.figure(figsize=(20,9))
ax = fig.add_subplot(121)

ax2 = fig.add_subplot(122)

ax.hist(prepped_math['math score'], color = 'blue', edgecolor='black', bins= 'auto')

# Labels
ax.set_title('Math Scores of Prep Course Students')
ax.set_xlabel('Math Scores'); ax.set_ylabel('Number of Prep Course Students');

ax2.hist(not_prepped_math['math score'], color = 'blue', edgecolor='black', bins= 'auto')
# Labels
ax2.set_title('Math Scores of Non-Prep Course Students')
ax2.set_xlabel('Math Scores'); ax2.set_ylabel('Number of Non-Prep Course Students');

# %%
# sns.set(style='darkgrid', color_codes=True)

# Set up the matplotlib figure
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,9), sharex=False)
sns.despine(left=True)

   
sns.distplot(prepped_math, bins = 'auto', kde=False, rug=False, 
             ax=axes[0]).set(xlabel = "Math Scores", 
                                 ylabel='# of Prep Course Students',
                                 title='Math Scores of Prep Course Students')

sns.distplot(not_prepped_math, bins = 'auto', kde=False, rug=False, 
             ax=axes[1]).set(xlabel = "Math Scores", 
                                 ylabel='# of Non-Prep Course Students',
                                 title='Math Scores of Non-Prep Course Students')
# Out:
# [Text(0, 0.5, '# of Non-Prep Course Students'),
#  Text(0.5, 0, 'Math Scores'),
#  Text(0.5, 1.0, 'Math Scores of Non-Prep Course Students')]
